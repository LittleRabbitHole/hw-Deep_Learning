# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(dictionary.keys()[:5])
print(reverse_dictionary.keys()[:5])
print(dictionary['fawn'])
print(reverse_dictionary[45848])
# Out:
# ['fawn', 'homomorphism', 'nordisk', 'nunnery', 'chthonic']
# [0, 1, 2, 3, 4]
# 45848
# fawn

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(30, valid_window + 30), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.036629
# Nearest to has: joaqu, dissolves, kibo, photosynthesis, macias, atonality, collation, hughes,
# Nearest to united: tolerable, propyl, bearing, children, selig, alongside, mergers, descending,
# Nearest to some: berthe, meteorite, mycenae, pyrenees, electrocution, oblivious, inhibit, commuting,
# Nearest to years: concourse, continents, compensation, outfielders, arizona, skid, delicacy, suk,
# Nearest to up: musicianship, brad, hyperplasia, computational, reformers, variadic, amalric, wend,
# Nearest to but: disgrace, neale, pardoned, uttered, deltas, mentioned, ultrasound, piss,
# Nearest to their: borneo, sala, asb, emiliano, homicide, feast, psycho, tamburlaine,
# Nearest to such: hardest, head, librarian, contents, candy, ppm, houser, gambling,
# Nearest to often: cker, ablation, ibis, oxidant, distortion, dhabi, aml, defaults,
# Nearest to at: nutrition, anomalies, mudd, cyanobacteria, abstain, cab, shingles, damien,
# Nearest to its: vm, raison, perfecting, euskadi, tribute, b, clouded, moses,
# Nearest to first: billings, castlereagh, sanjaks, deprivation, naive, guanosine, hoff, sei,
# Nearest to these: alderney, tainted, diger, musicology, wma, filling, qutb, servo,
# Nearest to into: blink, imf, strengthen, emery, audiences, rushdie, adopts, denning,
# Nearest to other: lewiston, flashlight, unsafe, marceau, anal, atlantans, fittings, gracie,
# Nearest to part: oro, redness, anthologies, edict, effecting, tit, converge, christianization,
# Average loss at step 2000: 4.370256
# Average loss at step 4000: 3.895495
# Average loss at step 6000: 3.698069
# Average loss at step 8000: 3.636428
# Average loss at step 10000: 3.673082
# Nearest to has: had, was, is, have, berbers, hawick, kibo, tata,
# Nearest to united: tolerable, propyl, fahd, bearing, bub, dalnet, country, damme,
# Nearest to some: many, these, berthe, other, eleven, the, several, transmissible,
# Nearest to years: echelon, dividends, lives, delicacy, eritreans, installment, times, sugarcubes,
# Nearest to up: brad, calculations, gyatso, glasnevin, shoulders, kekul, amalric, listeners,
# Nearest to but: however, that, counterweight, mini, flanks, medi, and, deltas,
# Nearest to their: his, the, sandstorms, its, liquor, homicide, hippocrates, newsreel,
# Nearest to such: houser, remus, gambling, librarian, directional, freak, well, agglutinative,
# Nearest to often: ablation, usually, cpi, cker, oxidant, ridley, equalizer, courtier,
# Nearest to at: in, on, into, caverns, from, nutrition, ogg, cyanobacteria,
# Nearest to its: the, his, their, vm, perimeter, generically, perfecting, vocalist,
# Nearest to first: second, shotguns, gow, shortness, ballard, floated, indicating, iceberg,
# Nearest to these: many, some, tainted, school, alderney, wma, qutb, iast,
# Nearest to into: sichuan, with, from, at, kristofferson, exhorted, blink, dreamcast,
# Nearest to other: ideas, some, various, inklings, vall, marceau, inborn, december,
# Nearest to part: anthologies, kotzebue, redness, internally, vermilion, mujahideen, effecting, wen,
# Average loss at step 12000: 3.654284
# Average loss at step 14000: 3.650902
# Average loss at step 16000: 3.591036
# Average loss at step 18000: 3.573374
# Average loss at step 20000: 3.437650
# Nearest to has: had, have, is, was, bahadur, erroneous, berbers, subregion,
# Nearest to united: tolerable, propyl, fahd, dalnet, country, squandered, contractors, hiberno,
# Nearest to some: many, these, all, most, mckinley, several, other, any,
# Nearest to years: times, echelon, dividends, year, eritreans, foot, skid, concourse,
# Nearest to up: gyatso, him, calculations, glasnevin, listeners, brad, kekul, slides,
# Nearest to but: however, counterweight, which, and, when, are, novelette, although,
# Nearest to their: its, his, the, psychiatry, newsreel, sandstorms, generically, liquor,
# Nearest to such: well, these, many, ary, cartoonish, controllable, known, remus,
# Nearest to often: usually, ablation, cpi, equalizer, courtier, generally, also, honneur,
# Nearest to at: in, caverns, marpol, heathland, theaters, altman, nutrition, despite,
# Nearest to its: their, his, the, suburb, her, perimeter, vocalist, generically,
# Nearest to first: second, last, shortness, under, same, government, esoteric, ballard,
# Nearest to these: many, some, all, such, qutb, stretching, ogle, they,
# Nearest to into: from, sichuan, with, fonts, dreamcast, blink, to, hashemite,
# Nearest to other: various, some, slide, including, balkan, vall, different, many,
# Nearest to part: anthologies, effecting, warden, mujahideen, edict, redness, role, christianization,
# Average loss at step 22000: 3.395238
# Average loss at step 24000: 3.546797
# Average loss at step 26000: 3.512319
# Average loss at step 28000: 3.475819
# Average loss at step 30000: 3.489462
# Nearest to has: had, have, is, was, boasts, berbers, aug, bahadur,
# Nearest to united: tolerable, fahd, propyl, contractors, bearing, dalnet, abbeville, hiberno,
# Nearest to some: many, these, all, any, several, various, other, mckinley,
# Nearest to years: times, year, days, dividends, echelon, eritreans, months, persia,
# Nearest to up: him, gyatso, them, out, listeners, slides, calculations, glasnevin,
# Nearest to but: however, and, although, when, or, though, while, panoramic,
# Nearest to their: its, his, the, her, some, any, newsreel, these,
# Nearest to such: these, well, many, known, ary, far, ankles, venturi,
# Nearest to often: usually, sometimes, commonly, generally, also, widely, cpi, there,
# Nearest to at: on, nutrition, heathland, during, altman, theaters, melanchthon, under,
# Nearest to its: their, his, the, her, cooperatives, generically, suburb, any,
# Nearest to first: second, last, shortness, same, ceo, next, government, wallenberg,
# Nearest to these: many, some, such, all, are, several, were, they,
# Nearest to into: from, with, fonts, sichuan, within, blink, under, dreamcast,
# Nearest to other: various, different, some, many, including, more, lichtenberg, slide,
# Nearest to part: anthologies, christianization, effecting, warden, camillo, understood, role, fable,
# Average loss at step 32000: 3.518116
# Average loss at step 34000: 3.377996
# Average loss at step 36000: 3.432135
# Average loss at step 38000: 3.461685
# Average loss at step 40000: 3.507769
# Nearest to has: had, have, was, is, boasts, berbers, aug, although,
# Nearest to united: tolerable, propyl, fahd, mulligan, oracular, bearing, mummified, expounded,
# Nearest to some: many, these, several, all, any, both, various, certain,
# Nearest to years: days, times, year, months, echelon, dividends, immunoglobulins, persia,
# Nearest to up: out, him, them, gyatso, off, listeners, down, slides,
# Nearest to but: however, although, while, and, though, or, which, see,
# Nearest to their: its, his, the, her, your, any, some, throughput,
# Nearest to such: these, well, known, many, including, ary, some, far,
# Nearest to often: usually, sometimes, commonly, generally, still, also, widely, now,
# Nearest to at: in, from, during, on, under, sailplane, altman, sinfonia,
# Nearest to its: their, his, the, her, cooperatives, some, your, intentions,
# Nearest to first: second, last, next, same, third, shortness, augusta, sheer,
# Nearest to these: some, many, such, several, all, they, are, which,
# Nearest to into: from, through, with, sichuan, fonts, within, portability, purging,
# Nearest to other: various, different, including, stepmania, smaller, slide, genji, ideas,
# Nearest to part: role, camillo, christianization, anthologies, number, fable, effecting, understood,
# Average loss at step 42000: 3.487660
# Average loss at step 44000: 3.476573
# Average loss at step 46000: 3.441766
# Average loss at step 48000: 3.430719
# Average loss at step 50000: 3.460556
# Nearest to has: had, have, is, was, since, boasts, includes, bahadur,
# Nearest to united: tolerable, fahd, mulligan, propyl, expounded, oracular, mummified, rest,
# Nearest to some: many, these, several, the, any, mckinley, certain, historians,
# Nearest to years: days, months, year, decades, weeks, echelon, times, lal,
# Nearest to up: out, him, them, off, gyatso, down, back, slides,
# Nearest to but: however, although, while, though, and, or, which, he,
# Nearest to their: its, his, her, the, your, some, our, these,
# Nearest to such: well, known, these, many, including, ary, venturi, regarded,
# Nearest to often: usually, sometimes, generally, commonly, also, widely, still, now,
# Nearest to at: loyola, under, during, theaters, sinfonia, cater, in, heathland,
# Nearest to its: their, his, the, her, some, cooperatives, lookups, your,
# Nearest to first: second, last, third, esoteric, next, final, same, shortness,
# Nearest to these: many, some, several, such, all, those, the, which,
# Nearest to into: through, from, kristofferson, between, portability, up, fonts, imf,
# Nearest to other: various, including, lichtenberg, different, specific, slide, applicants, smaller,
# Nearest to part: role, parts, understood, kind, number, effecting, anthologies, camillo,
# Average loss at step 52000: 3.337543
# Average loss at step 54000: 3.433389
# Average loss at step 56000: 3.330663
# Average loss at step 58000: 3.408215
# Average loss at step 60000: 3.401411
# Nearest to has: had, have, is, was, since, jeb, gita, bahadur,
# Nearest to united: tolerable, expounded, fahd, mulligan, propyl, mummified, rest, oracular,
# Nearest to some: many, these, several, any, those, certain, all, historians,
# Nearest to years: days, months, year, decades, weeks, times, catarina, echelon,
# Nearest to up: out, off, him, them, gyatso, down, slides, listeners,
# Nearest to but: however, although, though, while, and, which, especially, where,
# Nearest to their: his, its, her, your, our, newsreel, some, these,
# Nearest to such: well, known, many, these, ary, ankles, including, venturi,
# Nearest to often: usually, sometimes, commonly, generally, still, widely, also, frequently,
# Nearest to at: in, during, under, from, after, bandar, sinfonia, on,
# Nearest to its: their, his, her, the, lookups, ged, cooperatives, throughput,
# Nearest to first: second, last, third, next, final, shortness, colonels, esoteric,
# Nearest to these: some, many, several, all, those, such, they, which,
# Nearest to into: through, from, within, with, portability, between, fonts, kristofferson,
# Nearest to other: various, lichtenberg, different, including, balkan, slide, tumble, others,
# Nearest to part: parts, understood, number, role, anthologies, kind, fable, effecting,
# Average loss at step 62000: 3.408290
# Average loss at step 64000: 3.391573
# Average loss at step 66000: 3.404633
# Average loss at step 68000: 3.323769
# Average loss at step 70000: 3.294320
# Nearest to has: had, have, is, was, aug, having, millionaire, bahadur,
# Nearest to united: tolerable, expounded, fahd, mulligan, propyl, mummified, descending, us,
# Nearest to some: many, several, these, certain, any, those, all, this,
# Nearest to years: days, months, year, times, decades, weeks, catarina, hours,
# Nearest to up: out, off, him, them, down, gyatso, listeners, slides,
# Nearest to but: however, although, though, and, than, where, which, it,
# Nearest to their: its, his, her, your, our, the, some, fatimids,
# Nearest to such: well, these, many, known, regarded, some, including, ary,
# Nearest to often: usually, sometimes, generally, commonly, still, also, widely, frequently,
# Nearest to at: in, during, ao, under, caverns, loyola, panyu, after,
# Nearest to its: their, his, her, the, cooperatives, your, lookups, throughput,
# Nearest to first: second, last, third, next, later, original, shortness, yelled,
# Nearest to these: many, several, some, all, those, such, they, which,
# Nearest to into: through, from, within, imf, across, portability, blink, pleading,
# Nearest to other: various, including, different, individual, others, slide, racquets, tumble,
# Nearest to part: parts, number, role, understood, kind, fable, camillo, variety,
# Average loss at step 72000: 3.364757
# Average loss at step 74000: 3.366215
# Average loss at step 76000: 3.372685
# Average loss at step 78000: 3.371435
# Average loss at step 80000: 3.359675
# Nearest to has: had, have, is, was, since, aug, verdeans, having,
# Nearest to united: tolerable, expounded, mulligan, fahd, mummified, descending, propyl, rest,
# Nearest to some: many, several, these, those, any, various, most, all,
# Nearest to years: days, months, year, times, decades, weeks, hours, minutes,
# Nearest to up: off, out, down, them, listeners, him, back, gyatso,
# Nearest to but: however, although, though, and, while, that, which, loaders,
# Nearest to their: his, its, her, our, your, the, my, these,
# Nearest to such: these, well, including, known, many, regarded, certain, having,
# Nearest to often: usually, sometimes, commonly, generally, still, widely, frequently, also,
# Nearest to at: in, bandar, during, near, under, loyola, imre, sena,
# Nearest to its: their, his, the, her, lookups, suburb, gaines, tonight,
# Nearest to first: second, last, third, next, same, shortness, previous, lancers,
# Nearest to these: many, some, several, such, those, various, all, their,
# Nearest to into: through, from, within, between, portability, across, under, blink,
# Nearest to other: various, including, different, slide, individual, balkan, others, stepmania,
# Nearest to part: number, parts, kind, understood, role, fable, piece, variety,
# Average loss at step 82000: 3.332143
# Average loss at step 84000: 3.231179
# Average loss at step 86000: 3.317791
# Average loss at step 88000: 3.246662
# Average loss at step 90000: 3.298540
# Nearest to has: had, have, is, was, since, aug, having, verdeans,
# Nearest to united: tolerable, expounded, fahd, descending, mulligan, propyl, constitution, us,
# Nearest to some: many, several, these, various, any, certain, both, all,
# Nearest to years: days, months, year, decades, times, weeks, minutes, hours,
# Nearest to up: off, down, out, them, him, forward, back, gyatso,
# Nearest to but: however, although, though, while, and, assures, psychoactive, layered,
# Nearest to their: his, its, her, your, our, the, my, both,
# Nearest to such: these, well, known, certain, regarded, having, including, many,
# Nearest to often: usually, sometimes, commonly, generally, typically, widely, frequently, still,
# Nearest to at: in, near, on, under, ao, before, during, dek,
# Nearest to its: their, his, the, her, lookups, cardiac, cooperatives, gorgias,
# Nearest to first: second, last, third, next, same, previous, shortness, crusades,
# Nearest to these: several, some, many, such, those, various, both, all,
# Nearest to into: through, within, under, portability, from, blink, pleading, kristofferson,
# Nearest to other: various, different, individual, stepmania, slide, pests, lichtenberg, smaller,
# Nearest to part: parts, number, kind, role, goodies, variety, understood, piece,
# Average loss at step 92000: 3.330207
# Average loss at step 94000: 3.227117
# Average loss at step 96000: 3.356090
# Average loss at step 98000: 3.343178
# Average loss at step 100000: 3.317769
# Nearest to has: had, have, was, is, since, having, msi, aug,
# Nearest to united: tolerable, expounded, fahd, us, mulligan, constitution, descending, kops,
# Nearest to some: many, several, these, various, any, all, certain, those,
# Nearest to years: days, months, weeks, decades, year, times, minutes, hours,
# Nearest to up: off, out, him, down, them, back, listeners, forward,
# Nearest to but: however, although, though, and, while, punching, which, ordovician,
# Nearest to their: its, his, her, our, your, my, the, these,
# Nearest to such: these, well, known, many, having, including, ary, regarded,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, now, widely,
# Nearest to at: near, under, in, zohar, dek, ao, during, university,
# Nearest to its: their, his, her, the, lookups, cardiac, britons, instructed,
# Nearest to first: second, last, next, third, final, same, colonels, crusades,
# Nearest to these: some, several, many, such, those, various, certain, their,
# Nearest to into: through, within, portability, blink, khazars, across, kristofferson, from,
# Nearest to other: various, individual, different, smaller, including, balkan, stepmania, pests,
# Nearest to part: parts, kind, number, role, variety, result, goodies, understood,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# generate a training batch
data_index = 0

def generate_batch(batch_size, nb_window):
  global data_index
  #assert batch_size % num_skips == 0
  #assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, nb_window), dtype=np.int32) # use half of neighbours
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * nb_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    sample = nb_window  # target label at the center of the buffer
    samples_to_avoid = [ nb_window ]
    for j in range(nb_window):
      while sample in samples_to_avoid:
        sample = random.randint(0, span - 1)
      samples_to_avoid.append(sample)
      batch[i, j] = buffer[sample]
    labels[i] = buffer[nb_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for nb_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, nb_window=nb_window)
    print('\nwith nb_window = %d:' % (nb_window))
    print('    batch:', [[reverse_dictionary[bj] for bj in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with nb_window = 2:
#     batch: [['term', 'a'], ['of', 'as'], ['as', 'a'], ['a', 'abuse'], ['of', 'term'], ['abuse', 'of'], ['against', 'first'], ['used', 'first']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with nb_window = 4:
#     batch: [['first', 'as', 'a', 'originated'], ['first', 'against', 'term', 'a'], ['used', 'early', 'of', 'term'], ['of', 'against', 'used', 'term'], ['term', 'abuse', 'first', 'early'], ['class', 'abuse', 'used', 'early'], ['first', 'radicals', 'against', 'used'], ['radicals', 'used', 'early', 'the']]
#     labels: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
nb_window = 2 # How many words to consider left and right.
#num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
#valid_size = 16 # Random set of words to evaluate similarity on.
#valid_window = 100 # Only pick dev samples in the head of the distribution.
#valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, nb_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed,1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, nb_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.492265
# Nearest to has: amaranth, toe, rhine, khosrau, summarize, crusade, lugo, multicast,
# Nearest to united: tiptree, manifestation, ids, buckminster, dct, lightfoot, commercialism, unscrupulous,
# Nearest to some: fascinated, engravers, trojan, hectic, immorality, eikon, penetration, arnauld,
# Nearest to years: forest, nightingale, lecompton, curiosity, highlight, rehearsing, donner, medications,
# Nearest to up: timbuktu, arched, deploying, fiercely, falconiformes, seventies, pros, hanoi,
# Nearest to but: nancy, presentation, flipping, fetal, almagro, roamed, parkes, prefrontal,
# Nearest to their: irradiation, castrato, shining, conceptualization, bidding, adolph, thereupon, leblanc,
# Nearest to such: liquids, successor, harm, operative, monazite, referees, that, implosive,
# Nearest to often: channels, bess, wildfire, gch, cbc, intersystems, hemoglobin, antisymmetric,
# Nearest to at: edict, nominates, ethnically, krakatoa, hussein, woodpecker, emigre, planina,
# Nearest to its: email, inexplicable, bursting, engel, spherical, bckgr, detergents, chromosomal,
# Nearest to first: tachi, shepard, tricyclic, alcoholics, jacob, animation, oxfordshire, reconciling,
# Nearest to these: celebrities, formalized, repeatable, exploded, jerome, toussaint, worms, lines,
# Nearest to into: glut, inhabitants, jurgen, halftime, judo, guarding, mala, lao,
# Nearest to other: minsky, alioth, loaned, province, csx, riot, hainan, mating,
# Nearest to part: handlebar, nigsberg, tristan, enforceable, consummate, horseshoe, safely, tsuba,
# Average loss at step 2000: 4.517015
# Average loss at step 4000: 4.054736
# Average loss at step 6000: 3.903687
# Average loss at step 8000: 3.759048
# Average loss at step 10000: 3.743200
# Nearest to has: had, have, is, was, poked, unbroken, toe, interquartile,
# Nearest to united: manifestation, ids, overthrow, redrawing, tiptree, employ, atari, valencia,
# Nearest to some: many, other, these, yuga, vote, prostate, that, schilling,
# Nearest to years: raeder, fibre, leonardo, ft, highlight, rehearsing, minivans, garlic,
# Nearest to up: timbuktu, falconiformes, ores, nyasa, seventies, planet, belt, convey,
# Nearest to but: which, binge, hco, tat, and, appropriation, cabo, magnitudes,
# Nearest to their: his, its, another, sweetened, sinope, tors, chivalry, some,
# Nearest to such: well, prolific, neoplatonic, purge, sardonic, stresemann, ecotourism, norms,
# Nearest to often: also, hemoglobin, bess, antisymmetric, gch, inert, derleth, deals,
# Nearest to at: in, sound, on, of, islington, skirmishes, secretaries, from,
# Nearest to its: their, the, notorious, an, his, a, mss, animator,
# Nearest to first: tachi, same, running, typing, hybrids, tricyclic, lucasarts, horner,
# Nearest to these: other, many, unauthorised, some, buckwheat, repeatable, exploded, celebrities,
# Nearest to into: from, judo, corresponded, mafiosi, motets, newport, doreen, inhabitants,
# Nearest to other: some, many, these, parmenides, laver, are, cms, province,
# Nearest to part: tristan, horseshoe, micros, hasse, emerges, elo, gopher, irix,
# Average loss at step 12000: 3.750901
# Average loss at step 14000: 3.730205
# Average loss at step 16000: 3.737432
# Average loss at step 18000: 3.723711
# Average loss at step 20000: 3.584138
# Nearest to has: had, have, is, was, lodgings, falsetto, levantine, mourned,
# Nearest to united: manifestation, overthrow, ids, redrawing, tiptree, theocratic, employ, condominium,
# Nearest to some: many, other, these, all, most, several, both, their,
# Nearest to years: repeaters, raeder, minivans, year, fibre, leonardo, rehearsing, lecompton,
# Nearest to up: timbuktu, out, falconiformes, nyasa, smells, convey, slovakian, hymnal,
# Nearest to but: however, and, although, leaderships, while, there, vanunu, tat,
# Nearest to their: its, his, the, her, singapore, other, some, mishna,
# Nearest to such: well, prolific, herbert, ecotourism, these, cinque, known, stresemann,
# Nearest to often: also, commonly, which, antisymmetric, not, always, sometimes, bess,
# Nearest to at: when, esther, mangrove, predator, sound, radioactive, payoff, islington,
# Nearest to its: their, his, the, glans, several, engage, ecb, notorious,
# Nearest to first: second, same, dfts, scalia, virtuous, typing, terrifying, cantus,
# Nearest to these: other, many, some, various, buckwheat, all, they, uruguayan,
# Nearest to into: from, corresponded, fool, doreen, yeah, motets, newport, mafiosi,
# Nearest to other: these, some, different, many, their, parmenides, both, various,
# Nearest to part: tristan, micros, emerges, remedies, development, elo, mojo, because,
# Average loss at step 22000: 3.696691
# Average loss at step 24000: 3.643694
# Average loss at step 26000: 3.618792
# Average loss at step 28000: 3.658555
# Average loss at step 30000: 3.628468
# Nearest to has: had, have, is, was, having, lodgings, mourned, steinmetz,
# Nearest to united: manifestation, overthrow, ids, redrawing, theocratic, mismanagement, tiptree, fundamentalism,
# Nearest to some: many, several, these, all, various, other, most, certain,
# Nearest to years: year, months, repeaters, forage, raeder, days, atsc, garlic,
# Nearest to up: out, off, down, back, pura, them, smells, ores,
# Nearest to but: however, although, itosu, than, and, though, while, francium,
# Nearest to their: its, his, her, the, avogadro, these, isometric, your,
# Nearest to such: well, prolific, known, cinque, ecotourism, enshrined, drew, graceful,
# Nearest to often: sometimes, commonly, also, usually, frequently, hemoglobin, which, princesses,
# Nearest to at: evas, corrosion, adt, aberystwyth, suspend, schema, ibo, escobar,
# Nearest to its: their, his, the, engage, endorsed, mss, miserable, primrose,
# Nearest to first: second, same, inkjet, last, terrifying, core, reverts, conglomerate,
# Nearest to these: various, other, many, some, different, several, both, all,
# Nearest to into: motets, from, through, yeah, breathes, corresponded, fool, in,
# Nearest to other: these, different, various, many, some, both, travolta, several,
# Nearest to part: tristan, number, role, mojo, micros, micromachining, result, tinymud,
# Average loss at step 32000: 3.447890
# Average loss at step 34000: 3.609901
# Average loss at step 36000: 3.592917
# Average loss at step 38000: 3.546167
# Average loss at step 40000: 3.567025
# Nearest to has: had, have, was, having, is, steinmetz, disseminate, flyby,
# Nearest to united: overthrow, manifestation, aclu, mismanagement, theocratic, valencia, tiptree, incompetent,
# Nearest to some: many, all, several, these, various, both, most, other,
# Nearest to years: year, days, months, raeder, times, zaragoza, repeaters, fibre,
# Nearest to up: out, off, away, down, pura, them, smells, slovakian,
# Nearest to but: however, although, and, than, while, there, very, when,
# Nearest to their: its, his, her, the, your, lifestyles, yearning, these,
# Nearest to such: well, known, ecotourism, graceful, follows, referred, bhakti, enshrined,
# Nearest to often: sometimes, commonly, usually, frequently, also, generally, still, being,
# Nearest to at: schema, snacks, evas, steppenwolf, after, ethnically, during, islington,
# Nearest to its: their, his, the, her, isometric, hoped, engage, your,
# Nearest to first: second, same, last, third, core, crashes, original, best,
# Nearest to these: various, many, all, some, several, certain, both, other,
# Nearest to into: through, from, corresponded, down, around, workarounds, piety, motets,
# Nearest to other: various, different, some, these, several, restrictions, examination, many,
# Nearest to part: number, result, parts, micromachining, side, tristan, montauban, case,
# Average loss at step 42000: 3.615972
# Average loss at step 44000: 3.578024
# Average loss at step 46000: 3.576546
# Average loss at step 48000: 3.500907
# Average loss at step 50000: 3.492394
# Nearest to has: had, have, having, is, since, involuntarily, was, workmanship,
# Nearest to united: overthrow, manifestation, incompetent, tiptree, theocratic, aclu, intellivision, warn,
# Nearest to some: many, several, various, most, all, these, seo, those,
# Nearest to years: year, months, days, times, decades, weeks, hussein, repeaters,
# Nearest to up: out, off, back, them, down, away, him, pura,
# Nearest to but: although, because, however, and, while, than, zhuang, brisance,
# Nearest to their: its, his, your, her, other, lifestyles, our, various,
# Nearest to such: well, known, prolific, follows, ecotourism, moog, liberalism, murray,
# Nearest to often: usually, sometimes, commonly, generally, frequently, widely, still, being,
# Nearest to at: during, evas, kripke, schema, tuireadh, in, near, traversing,
# Nearest to its: their, his, the, her, hoped, diabelli, your, pesos,
# Nearest to first: same, second, last, original, next, final, best, core,
# Nearest to these: many, various, certain, some, all, several, different, other,
# Nearest to into: through, from, out, around, somerset, up, down, corresponded,
# Nearest to other: various, different, these, their, many, several, travolta, restrictions,
# Nearest to part: result, parts, form, number, case, role, series, lot,
# Average loss at step 52000: 3.525468
# Average loss at step 54000: 3.540756
# Average loss at step 56000: 3.413355
# Average loss at step 58000: 3.489740
# Average loss at step 60000: 3.521040
# Nearest to has: had, have, is, having, was, falsetto, includes, langley,
# Nearest to united: overthrow, warn, manifestation, intellivision, aclu, tiptree, incompetent, dhahran,
# Nearest to some: many, several, most, various, all, both, certain, japonic,
# Nearest to years: months, days, year, decades, weeks, minutes, times, jumbled,
# Nearest to up: out, off, back, away, down, perpetually, them, pura,
# Nearest to but: however, although, though, and, than, while, almost, troposphere,
# Nearest to their: its, his, her, the, our, your, lifestyles, my,
# Nearest to such: well, known, stresemann, liberalism, described, decryption, graceful, ecotourism,
# Nearest to often: sometimes, commonly, usually, generally, widely, frequently, still, likely,
# Nearest to at: near, during, in, aberystwyth, on, animist, spinning, under,
# Nearest to its: their, his, the, her, chandrasekhar, constipation, mediator, scouring,
# Nearest to first: second, last, next, same, ergot, townhouse, inkjet, nontrivial,
# Nearest to these: various, all, many, other, several, certain, examples, both,
# Nearest to into: through, from, within, fool, out, down, suo, back,
# Nearest to other: various, these, many, different, several, both, travolta, hora,
# Nearest to part: result, parts, form, role, case, number, portion, much,
# Average loss at step 62000: 3.481084
# Average loss at step 64000: 3.414140
# Average loss at step 66000: 3.434320
# Average loss at step 68000: 3.381071
# Average loss at step 70000: 3.491708
# Nearest to has: had, have, having, is, includes, was, poked, radix,
# Nearest to united: overthrow, tiptree, warn, pots, commonwealth, freshman, manifestation, bau,
# Nearest to some: many, several, various, these, all, certain, other, most,
# Nearest to years: months, days, year, weeks, month, minutes, decades, percent,
# Nearest to up: out, down, off, back, away, them, him, pura,
# Nearest to but: although, however, though, because, while, and, which, than,
# Nearest to their: its, his, her, lifestyles, your, our, both, the,
# Nearest to such: well, known, graceful, follows, ecotourism, described, result, include,
# Nearest to often: sometimes, usually, generally, commonly, widely, still, typically, now,
# Nearest to at: during, withered, near, through, lieutenants, feb, before, in,
# Nearest to its: their, his, her, the, dukkha, pesos, finalists, lemmy,
# Nearest to first: second, last, same, next, original, arran, following, core,
# Nearest to these: various, some, several, many, certain, those, different, other,
# Nearest to into: through, within, out, around, in, down, somerset, behind,
# Nearest to other: various, many, different, these, some, several, certain, restrictions,
# Nearest to part: result, parts, episode, form, role, case, number, question,
# Average loss at step 72000: 3.449259
# Average loss at step 74000: 3.377505
# Average loss at step 76000: 3.489706
# Average loss at step 78000: 3.494185
# Average loss at step 80000: 3.386738
# Nearest to has: had, have, having, is, was, includes, allows, elaborates,
# Nearest to united: overthrow, manifestation, commonwealth, warn, tiptree, dhahran, arrived, pots,
# Nearest to some: many, several, various, most, all, these, certain, both,
# Nearest to years: months, days, year, weeks, decades, percent, centuries, minutes,
# Nearest to up: out, down, off, back, him, them, away, perpetually,
# Nearest to but: although, though, however, because, while, which, it, and,
# Nearest to their: its, his, her, the, your, lifestyles, my, our,
# Nearest to such: well, follows, misquoted, described, result, including, known, bhakti,
# Nearest to often: sometimes, usually, generally, commonly, frequently, widely, still, mostly,
# Nearest to at: during, near, pentagon, in, dealings, around, teutoburg, texcoco,
# Nearest to its: their, his, the, her, diabelli, toolbars, kafka, sled,
# Nearest to first: last, second, next, same, best, original, beginning, third,
# Nearest to these: various, several, some, certain, different, numerous, those, other,
# Nearest to into: through, within, across, out, somerset, down, behind, around,
# Nearest to other: various, different, many, certain, these, individual, some, those,
# Nearest to part: result, parts, number, portion, because, lot, role, member,
# Average loss at step 82000: 3.447216
# Average loss at step 84000: 3.424421
# Average loss at step 86000: 3.444358
# Average loss at step 88000: 3.461486
# Average loss at step 90000: 3.366531
# Nearest to has: had, have, is, having, allows, contains, was, involuntarily,
# Nearest to united: commonwealth, arrived, agricola, overthrow, bulb, warn, bau, inventors,
# Nearest to some: many, several, various, certain, most, all, these, both,
# Nearest to years: days, months, year, centuries, weeks, decades, percent, month,
# Nearest to up: down, off, back, out, away, perpetually, deprecated, into,
# Nearest to but: although, though, however, while, see, because, lecoq, unsubstantiated,
# Nearest to their: its, his, her, your, lifestyles, these, our, my,
# Nearest to such: well, described, result, follows, misquoted, known, many, mischievous,
# Nearest to often: sometimes, generally, usually, commonly, frequently, typically, now, widely,
# Nearest to at: near, around, during, hook, pentagon, neoclassicism, dealings, messagepad,
# Nearest to its: their, his, the, her, dukkha, lifestyles, gaining, intercity,
# Nearest to first: last, second, next, original, third, core, same, ergot,
# Nearest to these: various, different, many, several, certain, those, some, all,
# Nearest to into: through, down, across, out, somerset, zara, up, within,
# Nearest to other: various, different, these, certain, both, specific, many, travolta,
# Nearest to part: result, parts, number, role, lot, form, member, kind,
# Average loss at step 92000: 3.403146
# Average loss at step 94000: 3.408822
# Average loss at step 96000: 3.269032
# Average loss at step 98000: 3.035764
# Average loss at step 100000: 3.264500
# Nearest to has: had, have, having, includes, is, citrate, rupee, was,
# Nearest to united: commonwealth, arrived, bulb, us, member, bau, warn, plo,
# Nearest to some: many, several, various, certain, both, these, all, those,
# Nearest to years: months, days, year, centuries, weeks, decades, minutes, month,
# Nearest to up: off, down, out, back, away, him, samples, into,
# Nearest to but: although, though, and, however, while, because, if, or,
# Nearest to their: its, his, her, your, our, both, the, lifestyles,
# Nearest to such: well, described, result, follows, known, these, decryption, opposed,
# Nearest to often: sometimes, generally, usually, commonly, frequently, also, typically, widely,
# Nearest to at: near, around, evas, pentagon, during, teutoburg, suspend, towards,
# Nearest to its: their, his, her, the, toolbars, finalists, your, gaining,
# Nearest to first: last, second, next, third, same, swat, fourth, following,
# Nearest to these: various, several, other, those, certain, different, many, both,
# Nearest to into: through, down, across, within, back, out, from, off,
# Nearest to other: various, these, different, both, including, several, many, certain,
# Nearest to part: result, parts, role, member, number, episode, half, portion,

# %%
# plot
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
